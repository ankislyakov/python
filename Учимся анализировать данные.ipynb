# %%
import pandas as pd

# %%
df=pd.read_csv('/content/data.csv')
df
# Out:
#                                  region  municipality  ...  year            model
# 0      ru01 Республика Адыгея  (Адыгея)  Город Майкоп  ...  2006   Избираемый мэр
# 1      ru01 Республика Адыгея  (Адыгея)  Город Майкоп  ...  2007   Избираемый мэр
# 2      ru01 Республика Адыгея  (Адыгея)  Город Майкоп  ...  2008   Избираемый мэр
# 3      ru01 Республика Адыгея  (Адыгея)  Город Майкоп  ...  2009   Избираемый мэр
# 4      ru01 Республика Адыгея  (Адыгея)  Город Майкоп  ...  2010   Избираемый мэр
# ...                                 ...           ...  ...   ...              ...
# 30497           ru50 Московская область   Одинцовский  ...  2014     Сити-менджер
# 30498           ru50 Московская область   Одинцовский  ...  2015     Сити-менджер
# 30499           ru50 Московская область   Одинцовский  ...  2016  Назначаемый мэр
# 30500           ru50 Московская область   Одинцовский  ...  2017  Назначаемый мэр
# 30501           ru50 Московская область   Одинцовский  ...  2018  Назначаемый мэр
#
# [30502 rows x 6 columns]

# %% [markdown]
# Изучаем датасет

# %%
df.describe()
# Out:
#               oktmo          year
# count  3.050200e+04  30502.000000
# mean   5.917558e+07   2012.006032
# std    6.679118e+08      3.742669
# min    1.601000e+06   2006.000000
# 25%    2.470500e+07   2009.000000
# 50%    5.264600e+07   2012.000000
# 75%    7.365100e+07   2015.000000
# max    4.773700e+10   2018.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30502 entries, 0 to 30501
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   region        30502 non-null  object
#  1   municipality  30502 non-null  object
#  2   oktmo         30502 non-null  float64
#  3   mun_type      30502 non-null  object
#  4   year          30502 non-null  int64
#  5   model         29541 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df.columns
# Out:
# Index(['region', 'municipality', 'oktmo', 'mun_type', 'year', 'model'], dtype='object')

# %% [markdown]
# Фильтруем по строкам

# %%
df.loc[df['region'] == 'ru33 Владимирская область']
# Out:
#                           region  ...           model
# 10663  ru33 Владимирская область  ...  Избираемый мэр
# 10664  ru33 Владимирская область  ...  Избираемый мэр
# 10665  ru33 Владимирская область  ...  Избираемый мэр
# 10666  ru33 Владимирская область  ...  Избираемый мэр
# 10667  ru33 Владимирская область  ...  Избираемый мэр
# ...                          ...  ...             ...
# 10931  ru33 Владимирская область  ...    Сити-менджер
# 10932  ru33 Владимирская область  ...    Сити-менджер
# 10933  ru33 Владимирская область  ...    Сити-менджер
# 10934  ru33 Владимирская область  ...    Сити-менджер
# 10935  ru33 Владимирская область  ...    Сити-менджер
#
# [273 rows x 6 columns]

# %%
df.region.str.endswith('область')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 30497     True
# 30498     True
# 30499     True
# 30500     True
# 30501     True
# Name: region, Length: 30502, dtype: bool

# %%
df[df.region.str.endswith('область')]
# Out:
#                         region     municipality  ...  year            model
# 9135     ru28 Амурская область  город Свободный  ...  2006   Избираемый мэр
# 9136     ru28 Амурская область  город Свободный  ...  2007   Избираемый мэр
# 9137     ru28 Амурская область  город Свободный  ...  2008   Избираемый мэр
# 9138     ru28 Амурская область  город Свободный  ...  2009   Избираемый мэр
# 9139     ru28 Амурская область  город Свободный  ...  2010   Избираемый мэр
# ...                        ...              ...  ...   ...              ...
# 30497  ru50 Московская область      Одинцовский  ...  2014     Сити-менджер
# 30498  ru50 Московская область      Одинцовский  ...  2015     Сити-менджер
# 30499  ru50 Московская область      Одинцовский  ...  2016  Назначаемый мэр
# 30500  ru50 Московская область      Одинцовский  ...  2017  Назначаемый мэр
# 30501  ru50 Московская область      Одинцовский  ...  2018  Назначаемый мэр
#
# [18448 rows x 6 columns]

# %%
df[df.region.str.contains('Чел')]
# Out:
#                          region  ...           model
# 27222  ru74 Челябинская область  ...  Избираемый мэр
# 27223  ru74 Челябинская область  ...  Избираемый мэр
# 27224  ru74 Челябинская область  ...  Избираемый мэр
# 27225  ru74 Челябинская область  ...  Избираемый мэр
# 27226  ru74 Челябинская область  ...  Избираемый мэр
# ...                         ...  ...             ...
# 29801  ru74 Челябинская область  ...             NaN
# 29802  ru74 Челябинская область  ...             NaN
# 29803  ru74 Челябинская область  ...             NaN
# 29804  ru74 Челябинская область  ...             NaN
# 29805  ru74 Челябинская область  ...             NaN
#
# [559 rows x 6 columns]

# %%
Фильтрация по нескольким условиям

# %%
df[df.region.str.contains('ru33') & df.municipality.str.contains('Вязн')]
# Out:
#                           region  ...           model
# 10741  ru33 Владимирская область  ...  Избираемый мэр
# 10742  ru33 Владимирская область  ...  Избираемый мэр
# 10743  ru33 Владимирская область  ...  Избираемый мэр
# 10744  ru33 Владимирская область  ...  Избираемый мэр
# 10745  ru33 Владимирская область  ...    Сити-менджер
# 10746  ru33 Владимирская область  ...    Сити-менджер
# 10747  ru33 Владимирская область  ...    Сити-менджер
# 10748  ru33 Владимирская область  ...    Сити-менджер
# 10749  ru33 Владимирская область  ...    Сити-менджер
# 10750  ru33 Владимирская область  ...    Сити-менджер
# 10751  ru33 Владимирская область  ...    Сити-менджер
# 10752  ru33 Владимирская область  ...    Сити-менджер
# 10753  ru33 Владимирская область  ...    Сити-менджер
#
# [13 rows x 6 columns]

# %%
df[df.region.str.contains('ru33') & df.municipality.str.contains('Вязн') & (df['year'] <= 2009)]
# Out:
#                           region  ...           model
# 10741  ru33 Владимирская область  ...  Избираемый мэр
# 10742  ru33 Владимирская область  ...  Избираемый мэр
# 10743  ru33 Владимирская область  ...  Избираемый мэр
# 10744  ru33 Владимирская область  ...  Избираемый мэр
#
# [4 rows x 6 columns]

# %%
df[(df['region'].str.contains('ru33'))]
# Out:
#                           region  ...           model
# 10663  ru33 Владимирская область  ...  Избираемый мэр
# 10664  ru33 Владимирская область  ...  Избираемый мэр
# 10665  ru33 Владимирская область  ...  Избираемый мэр
# 10666  ru33 Владимирская область  ...  Избираемый мэр
# 10667  ru33 Владимирская область  ...  Избираемый мэр
# ...                          ...  ...             ...
# 10931  ru33 Владимирская область  ...    Сити-менджер
# 10932  ru33 Владимирская область  ...    Сити-менджер
# 10933  ru33 Владимирская область  ...    Сити-менджер
# 10934  ru33 Владимирская область  ...    Сити-менджер
# 10935  ru33 Владимирская область  ...    Сити-менджер
#
# [273 rows x 6 columns]

# %%
df[df['region'].str.startswith(('ru33', 'ru37'))]
# Out:
#                           region  ...            model
# 10663  ru33 Владимирская область  ...   Избираемый мэр
# 10664  ru33 Владимирская область  ...   Избираемый мэр
# 10665  ru33 Владимирская область  ...   Избираемый мэр
# 10666  ru33 Владимирская область  ...   Избираемый мэр
# 10667  ru33 Владимирская область  ...   Избираемый мэр
# ...                          ...  ...              ...
# 12588    ru37 Ивановская область  ...     Сити-менджер
# 12589    ru37 Ивановская область  ...  Назначаемый мэр
# 12590    ru37 Ивановская область  ...  Назначаемый мэр
# 12591    ru37 Ивановская область  ...  Назначаемый мэр
# 12592    ru37 Ивановская область  ...  Назначаемый мэр
#
# [624 rows x 6 columns]

# %% [markdown]
# Фильтруем по столбцам

# %%
df.region != 'ru74 Челябинская область'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 30497    True
# 30498    True
# 30499    True
# 30500    True
# 30501    True
# Name: region, Length: 30502, dtype: bool

# %%
df[df.region != 'ru74 Челябинская область']
# Out:
#                                  region  municipality  ...  year            model
# 0      ru01 Республика Адыгея  (Адыгея)  Город Майкоп  ...  2006   Избираемый мэр
# 1      ru01 Республика Адыгея  (Адыгея)  Город Майкоп  ...  2007   Избираемый мэр
# 2      ru01 Республика Адыгея  (Адыгея)  Город Майкоп  ...  2008   Избираемый мэр
# 3      ru01 Республика Адыгея  (Адыгея)  Город Майкоп  ...  2009   Избираемый мэр
# 4      ru01 Республика Адыгея  (Адыгея)  Город Майкоп  ...  2010   Избираемый мэр
# ...                                 ...           ...  ...   ...              ...
# 30497           ru50 Московская область   Одинцовский  ...  2014     Сити-менджер
# 30498           ru50 Московская область   Одинцовский  ...  2015     Сити-менджер
# 30499           ru50 Московская область   Одинцовский  ...  2016  Назначаемый мэр
# 30500           ru50 Московская область   Одинцовский  ...  2017  Назначаемый мэр
# 30501           ru50 Московская область   Одинцовский  ...  2018  Назначаемый мэр
#
# [29943 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['region', 'municipality', 'oktmo', 'mun_type', 'year', 'model'], dtype='object')

# %%
df[['region', 'municipality', 'mun_type', 'year', 'model']]
# Out:
#                                  region  municipality  ...  year            model
# 0      ru01 Республика Адыгея  (Адыгея)  Город Майкоп  ...  2006   Избираемый мэр
# 1      ru01 Республика Адыгея  (Адыгея)  Город Майкоп  ...  2007   Избираемый мэр
# 2      ru01 Республика Адыгея  (Адыгея)  Город Майкоп  ...  2008   Избираемый мэр
# 3      ru01 Республика Адыгея  (Адыгея)  Город Майкоп  ...  2009   Избираемый мэр
# 4      ru01 Республика Адыгея  (Адыгея)  Город Майкоп  ...  2010   Избираемый мэр
# ...                                 ...           ...  ...   ...              ...
# 30497           ru50 Московская область   Одинцовский  ...  2014     Сити-менджер
# 30498           ru50 Московская область   Одинцовский  ...  2015     Сити-менджер
# 30499           ru50 Московская область   Одинцовский  ...  2016  Назначаемый мэр
# 30500           ru50 Московская область   Одинцовский  ...  2017  Назначаемый мэр
# 30501           ru50 Московская область   Одинцовский  ...  2018  Назначаемый мэр
#
# [30502 rows x 5 columns]

# %% [markdown]
# ЗАДАНИЕ:
# 1. Узнать сколько в датасете областей
# 2. Сколько муниципалитетов во Владимрской области носят статус город
# 3. Сколько республик имеют хоть один муниципалитет с моделью управления "Сити-менджер"
# 4. Сколько муниципалитетов во Владимирской и Ивановской области вместе взятых
# 5. Сравнить в скольких муниципальных районах по состоянию на 2010 и 2018 г. модель управления была "Назначаемый мэр"
# 6. Сколько муниципалитетов в России имеют в своем названии топоним "Красн"
